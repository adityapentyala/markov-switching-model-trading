# %%
from backtesting import Strategy, Backtest
from strategy import get_MSM_startegy
import numpy as np
import pandas as pd
# Out:
# c:\Users\adity\markov-switching-model-trading\env\lib\site-packages\backtesting\_plotting.py:55: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support, such as old IDEs. Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="beae33ee-68b4-40b4-921a-b7e0890e0330">Loading BokehJS ...</span>
#     </div>

# %%
symbol = 'JINDALSAW'
df = pd.read_csv(f'../data/symbols/{symbol}.csv')
df['date'] = pd.to_datetime(df['date'])
df.set_index(df['date'], inplace=True)
ar_weights = np.load(f'../models/{symbol}.npy')

# %%
data = df[['open', 'high', 'low', 'close', 'returns']]
data = data.rename(columns={'open':'Open', 'high':'High', 'low':'Low', 'close':'Close'})

# %%
split = 0.7
train_data, test_data = data[:int(split*len(df))], data[int(split*len(df)):]
test_data = test_data.reset_index(drop=True)

# %%
train_data
# Out:
#                             Open   High    Low  Close   returns
# date
# 2015-02-01 00:00:00+05:30  40.40  43.10  35.70  39.00 -0.032258
# 2015-03-01 00:00:00+05:30  39.50  40.10  28.10  32.90 -0.156410
# 2015-04-01 00:00:00+05:30  32.90  36.30  30.50  34.45  0.047112
# 2015-05-01 00:00:00+05:30  34.60  37.30  29.90  30.70 -0.108853
# 2015-06-01 00:00:00+05:30  30.80  31.30  25.50  29.30 -0.045603
# ...                          ...    ...    ...    ...       ...
# 2022-01-01 00:00:00+05:30  49.65  59.70  49.00  50.20  0.016194
# 2022-02-01 00:00:00+05:30  50.50  54.20  40.00  43.40 -0.135458
# 2022-03-01 00:00:00+05:30  42.80  49.30  42.05  45.05  0.038018
# 2022-04-01 00:00:00+05:30  45.20  50.75  45.05  46.20  0.025527
# 2022-05-01 00:00:00+05:30  46.00  47.95  38.80  43.40 -0.060606
#
# [88 rows x 5 columns]

# %%
MSM_Strategy = get_MSM_startegy(ar_weights, data)

# %%
backtest = Backtest(data, MSM_Strategy)
backtest.run()
# Out:
# Start                     2015-02-01 00:00...
# End                       2025-07-01 00:00...
# Duration                   3803 days 00:00:00
# Exposure Time [%]                    65.07937
# Equity Final [$]                     44594.38
# Equity Peak [$]                      79197.25
# Return [%]                           345.9438
# Buy & Hold Return [%]               628.92019
# Return (Ann.) [%]                    15.30183
# Volatility (Ann.) [%]                47.64234
# CAGR [%]                              0.47285
# Sharpe Ratio                          0.32118
# Sortino Ratio                         0.68457
# Calmar Ratio                          0.21067
# Alpha [%]                           -59.44721
# Beta                                  0.64458
# Max. Drawdown [%]                   -72.63491
# Avg. Drawdown [%]                   -18.63066
# Max. Drawdown Duration     1977 days 00:00:00
# Avg. Drawdown Duration      311 days 00:00:00
# ...

# %%
backtest.plot()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_21088\3521804055.py:1: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   backtest.plot()
# c:\Users\adity\markov-switching-model-trading\env\lib\site-packages\bokeh\util\serialization.py:242: UserWarning: no explicit representation of timezones available for np.datetime64
#   return convert(array.astype("datetime64[us]"))
#   <div id="c514025f-00c2-4f89-8254-9a89505df11c" data-root-id="p1309" style="display: contents;"></div>
# GridPlot(id='p1309', ...)

# %%
train_backtest = Backtest(train_data, MSM_Strategy)
train_backtest.run()
# Out:
# Start                     2015-02-01 00:00...
# End                       2022-05-01 00:00...
# Duration                   2646 days 00:00:00
# Exposure Time [%]                    57.95455
# Equity Final [$]                      12169.3
# Equity Peak [$]                       26600.5
# Return [%]                             21.693
# Buy & Hold Return [%]                35.83725
# Return (Ann.) [%]                     2.71341
# Volatility (Ann.) [%]                37.82691
# CAGR [%]                              0.08908
# Sharpe Ratio                          0.07173
# Sortino Ratio                         0.11353
# Calmar Ratio                          0.03736
# Alpha [%]                             1.90306
# Beta                                  0.55222
# Max. Drawdown [%]                   -72.63491
# Avg. Drawdown [%]                   -22.87044
# Max. Drawdown Duration     1581 days 00:00:00
# Avg. Drawdown Duration      449 days 00:00:00
# ...

# %%
train_backtest.plot()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_21088\1222173776.py:1: UserWarning: Superimposed OHLC plot matches the original plot. Skipping.
#   train_backtest.plot()
# c:\Users\adity\markov-switching-model-trading\env\lib\site-packages\bokeh\util\serialization.py:242: UserWarning: no explicit representation of timezones available for np.datetime64
#   return convert(array.astype("datetime64[us]"))
#   <div id="fd24f3e4-4726-41d8-ac2a-1e935880d235" data-root-id="p1637" style="display: contents;"></div>
# GridPlot(id='p1637', ...)

# %%
test_backtest = Backtest(test_data, MSM_Strategy)
test_backtest.run()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_21088\1307586556.py:1: UserWarning: Data index is not datetime. Assuming simple periods, but `pd.DateTimeIndex` is advised.
#   test_backtest = Backtest(test_data, MSM_Strategy)
# Start                                     0.0
# End                                      37.0
# Duration                                 37.0
# Exposure Time [%]                    36.84211
# Equity Final [$]                       9545.7
# Equity Peak [$]                      16842.25
# Return [%]                             -4.543
# Buy & Hold Return [%]                 -2.3522
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     NaN
# Sharpe Ratio                              NaN
# Sortino Ratio                             NaN
# Calmar Ratio                              0.0
# Alpha [%]                            -3.88784
# Beta                                  0.27853
# Max. Drawdown [%]                   -43.32289
# ...

# %%
test_backtest.plot()
# Out:
#   <div id="a55f0566-91f9-4ac0-9206-96d52667afa7" data-root-id="p1963" style="display: contents;"></div>
# GridPlot(id='p1963', ...)
